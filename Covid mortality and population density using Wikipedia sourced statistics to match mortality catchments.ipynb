# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# set up for plotting
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
def annotate_points(x,y,t,offset=100,df=None, **kwargs):
    ax = plt.gca()
    if df is None:
        data = kwargs.pop('data')
    else:
        data=df.copy()
    for i,row in data.iterrows():
        ax.annotate(row[t], xy=(row[x]*1.01,row[y]))

# %%
# import manually compiled data on population, density and covid mortality statistics
df = pd.read_excel('./covid-data/covid_deaths_manual_notes_wikipedia_pop.xlsx')

# %%
df = df[~df['deaths_per_100k_pop'].isna()]

# %%
df
# Out:
#                              Region         Country            City  \
# 5                            Africa         Nigeria           Lagos
# 7                            Africa    South Africa    Johannesburg
# 10                             Asia           China       Guangzhou
# 11                             Asia           China        Shanghai
# 12                             Asia           India           Delhi
# 14                             Asia       Indonesia         Jakarta
# 15                             Asia           Japan           Osaka
# 16                             Asia           Japan           Tokyo
# 17                             Asia        Thailand         Bangkok
# 18                           Europe          France           Paris
# 19                           Europe         Germany          Berlin
# 20                           Europe           Italy           Milan
# 22                           Europe     Netherlands       Rotterdam
# 23                           Europe          Russia          Moscow
# 24                           Europe  United Kingdom      Birmingham
# 25                           Europe  United Kingdom          London
# 26                           Europe  United Kingdom      Manchester
# 27  Latin America and the Caribbean       Argentina    Buenos Aires
# 28  Latin America and the Caribbean          Brazil        Curitiba
# 29  Latin America and the Caribbean          Brazil         Goiânia
# 30  Latin America and the Caribbean          Brazil  Rio de Janeiro
# 31  Latin America and the Caribbean          Brazil       São Paulo
# 32  Latin America and the Caribbean          Mexico   Ciudad Juárez
# 33  Latin America and the Caribbean          Mexico     Mexico City
# 34  Latin America and the Caribbean          Mexico       Monterrey
# 35  Latin America and the Caribbean            Peru            Lima
# 36                 Northern America   United States         Chicago
# 37                 Northern America   United States          Dallas
# 38                 Northern America   United States         Detroit
# 39                 Northern America   United States         Houston
# 40                 Northern America   United States    Indianapolis
# 41                 Northern America   United States     Los Angeles
# 42                 Northern America   United States        New York
# 43                 Northern America   United States         Phoenix
# 46                          Oceania       Australia        Brisbane
# 47                          Oceania       Australia      Gold Coast
# 52                          Oceania     New Zealand        Auckland
#
#     pop_wikipedia  area_sqkm_wikipedia               catchment_wikipedia  \
# 5      21320000.0              2706.70                      Metropolitan
# 7       8000000.0              3357.00                             Urban
# 10     65594622.0             19870.40                      Metropolitan
# 11     41354149.0             14922.70                      Metropolitan
# 12     16787941.0              1484.00  Union Territory (administrative)
# 14     33430285.0              7062.50                      Metropolitan
# 15      8823358.0              1905.14                      Metropolitan
# 16     40700000.0             13452.00                      Metropolitan
# 17     14626225.0              7761.60                      Metropolitan
# 18     13024518.0             18940.70                      Metropolitan
# 19      6144600.0             30546.00                      Metropolitan
# 20      3236472.0              1575.00     Metropolitan (administrative)
# 22       651157.0               324.14                      Municipality
# 23     13010112.0              2561.50                       City proper
# 24      2919600.0               598.90                             Urban
# 25      9002488.0              1572.00            Total (Greater London)
# 26      2812569.0              1276.00                Greater Manchester
# 27     15624000.0              4758.00                      Metropolitan
# 28      3400100.0             15416.90                      Metropolitan
# 29      2654860.0               739.00                      Metropolitan
# 30     12280702.0              4539.80                      Metropolitan
# 31     22001281.0              7946.96                      Metropolitan
# 32      1501551.0               321.19                              City
# 33     21804515.0              7866.10                      Metropolitan
# 34      4689601.0              7657.50                      Metropolitan
# 35     10882757.0              2819.30                      Metropolitan
# 36      2746388.0               607.44                              City
# 37      2613539.0              2353.10                            County
# 38      1793561.0              1740.00                            County
# 39      2304580.0              1739.62                              City
# 40       977203.0              1043.80                            County
# 41      9861224.0             12310.00                            County
# 42      8804190.0              1223.59                              City
# 43      4420568.0             23890.00                            County
# 46      2560700.0             15842.00   Metropolitan (Greater Brisbane)
# 47       640778.0               414.30                              City
# 52      1463000.0               607.10          Urban (statistical area)
#
#     density_wikipedia  Cumulative deaths reported due to COVID-19  \
# 5         7876.750286                                       771.0
# 7         2383.080131                                     22143.0
# 10        3301.122373                                         8.0
# 11        2771.224309                                       595.0
# 12       11312.628706                                     26376.0
# 14        4733.491681                                     15304.0
# 15        4631.343628                                      5313.0
# 16        3025.572406                                      8700.0
# 17        1884.434266                                      7974.0
# 18         687.647130                                      6119.0
# 19         201.158908                                      4739.0
# 20        2054.902857                                     12399.0
# 22        2008.875794                                      1170.0
# 23        5079.098965                                     44677.0
# 24        4874.937385                                      3718.0
# 25        5726.773537                                     19102.0
# 26        2204.207680                                      1392.0
# 27        3283.732661                                     56553.0
# 28         220.543689                                     13129.0
# 29        3592.503383                                     10783.0
# 30        2705.119609                                     54705.0
# 31        2768.515382                                     76368.0
# 32        4674.961861                                      3223.0
# 33        2771.960056                                     53718.0
# 34         612.419327                                     12310.0
# 35        3860.091867                                      9734.0
# 36        4521.249835                                      7738.0
# 37        1110.679104                                      6820.0
# 38        1030.782184                                      8122.0
# 39        1324.760580                                     11176.0
# 40         936.197547                                      2910.0
# 41         801.074249                                     32324.0
# 42        7195.375902                                     35185.0
# 43         185.038426                                     17692.0
# 46         161.639944                                       804.0
# 47        1546.652184                                       261.0
# 52        2409.817164                                       118.0
#
#     deaths_per_100k_pop                                              Notes  \
# 5              3.616323  State; suprisingly small number, however most ...
# 7            276.787500  "Estimated number of excess natural deaths ......
# 10             0.012196  JHU has Guangdong province, a broader area wit...
# 11             1.438792  Verified GHS and Shanghai province area on Goo...
# 12           157.112775                                                NaN
# 14            45.778850  See latest data point of graph (estimate didn'...
# 15            60.215170                                                NaN
# 16            21.375921                                      Sum of Chiba,
# 17            54.518510                                                NaN
# 18            46.980625  "According to the latest report as of Tuesday ...
# 19            77.124630   State of Berlin is the city (it is surrounded...
# 20           383.102341  This is the provincial estimate, although the ...
# 22           179.680169                                                NaN
# 23           343.402117  Moscow is the city proper; JHU also has Moscow...
# 24           127.346212                                                NaN
# 25           212.185787  "The total number of COVID-19 deaths reported ...
# 26            49.492119                                                NaN
# 27           361.962366                                                NaN
# 28           386.135702                                                NaN
# 29           406.160777                                                NaN
# 30           445.454991                                                NaN
# 31           347.107062                                                NaN
# 32           214.644724                                                NaN
# 33           246.361820                                                NaN
# 34           262.495679                                                NaN
# 35            89.444247                                                NaN
# 36           281.751886                                                NaN
# 37           260.948851                                                NaN
# 38           452.842139                                                NaN
# 39           484.947366  JHU statistic is for Harris county Texas, whic...
# 40           297.788689                                                NaN
# 41           327.788924                                                NaN
# 42           399.639263                                                NaN
# 43           400.220062  This statistic is for Maricopa county, which i...
# 46            31.397665  The sum of Metro North and Metro South statist...
# 47            40.731735  Gold Coast Hospital and Health Service and reg...
# 52             8.065619                                                NaN
#
#                                           Data source Reported Date  \
# 5                      https://covid19.ncdc.gov.ng/#!    2022-08-15
# 7   https://www.samrc.ac.za/reports/report-weekly-...    2022-08-10
# 10  https://github.com/CSSEGISandData/COVID-19/blo...    2022-08-13
# 11  https://github.com/CSSEGISandData/COVID-19/blo...    2022-08-13
# 12  https://github.com/CSSEGISandData/COVID-19/blo...    2022-08-13
# 14  https://www.fast-trackcities.org/data-visualiz...    2022-07-15
# 15  https://github.com/CSSEGISandData/COVID-19/blo...    2022-08-13
# 16  https://github.com/CSSEGISandData/COVID-19/blo...    2022-08-13
# 17  https://www.fast-trackcities.org/data-visualiz...    2022-07-16
# 18  https://www.sortiraparis.com/news/coronavirus/...    2022-08-17
# 19  https://github.com/CSSEGISandData/COVID-19/blo...    2022-08-13
# 20  https://www.regione.lombardia.it/wps/portal/is...    2022-08-16
# 22  https://coronadashboard.government.nl/gemeente...    2022-08-16
# 23  https://github.com/CSSEGISandData/COVID-19/blo...    2022-08-13
# 24  https://lginform.local.gov.uk/reports/lgastand...    2022-08-14
# 25  https://data.london.gov.uk/dataset/coronavirus...    2022-08-08
# 26  https://lginform.local.gov.uk/reports/lgastand...    2022-08-08
# 27  https://drexel.edu/lac/data-evidence/covid-19/...    2022-05-29
# 28  https://drexel.edu/lac/data-evidence/covid-19/...    2022-04-24
# 29  https://drexel.edu/lac/data-evidence/covid-19/...    2022-04-24
# 30  https://drexel.edu/lac/data-evidence/covid-19/...    2022-04-24
# 31  https://drexel.edu/lac/data-evidence/covid-19/...    2022-04-24
# 32  https://drexel.edu/lac/data-evidence/covid-19/...    2022-06-06
# 33  https://drexel.edu/lac/data-evidence/covid-19/...    2022-06-06
# 34  https://drexel.edu/lac/data-evidence/covid-19/...    2022-06-06
# 35  https://drexel.edu/lac/data-evidence/covid-19/...    2022-06-06
# 36      https://drexel-uhc.shinyapps.io/bchc_covid19/    2022-06-26
# 37      https://drexel-uhc.shinyapps.io/bchc_covid19/    2022-06-26
# 38      https://drexel-uhc.shinyapps.io/bchc_covid19/    2022-06-26
# 39  https://github.com/CSSEGISandData/COVID-19/blo...    2022-08-13
# 40      https://drexel-uhc.shinyapps.io/bchc_covid19/    2022-06-26
# 41      https://drexel-uhc.shinyapps.io/bchc_covid19/    2022-06-26
# 42      https://drexel-uhc.shinyapps.io/bchc_covid19/    2022-06-26
# 43       https://www.azdhs.gov/covid19/data/index.php    2022-08-10
# 46  https://www.qld.gov.au/health/conditions/healt...    2022-08-17
# 47  https://www.qld.gov.au/health/conditions/healt...    2022-08-17
# 52  https://www.health.govt.nz/covid-19-novel-coro...    2022-08-17
#
#                                        Wikipedia page  \
# 5                 https://en.wikipedia.org/wiki/Lagos
# 7          https://en.wikipedia.org/wiki/Johannesburg
# 10            https://en.wikipedia.org/wiki/Guangzhou
# 11             https://en.wikipedia.org/wiki/Shanghai
# 12                https://en.wikipedia.org/wiki/Delhi
# 14              https://en.wikipedia.org/wiki/Jakarta
# 15     https://en.wikipedia.org/wiki/Osaka_Prefecture
# 16                https://en.wikipedia.org/wiki/Tokyo
# 17              https://en.wikipedia.org/wiki/Bangkok
# 18                https://en.wikipedia.org/wiki/Paris
# 19               https://en.wikipedia.org/wiki/Berlin
# 20  https://en.wikipedia.org/wiki/Metropolitan_Cit...
# 22            https://en.wikipedia.org/wiki/Rotterdam
# 23               https://en.wikipedia.org/wiki/Moscow
# 24           https://en.wikipedia.org/wiki/Birmingham
# 25       https://en.wikipedia.org/wiki/Greater_London
# 26   https://en.wikipedia.org/wiki/Greater_Manchester
# 27         https://en.wikipedia.org/wiki/Buenos_Aires
# 28             https://en.wikipedia.org/wiki/Curitiba
# 29         https://en.wikipedia.org/wiki/Goi%C3%A2nia
# 30       https://en.wikipedia.org/wiki/Rio_de_Janeiro
# 31       https://en.wikipedia.org/wiki/S%C3%A3o_Paulo
# 32   https://en.wikipedia.org/wiki/Ciudad_Ju%C3%A1rez
# 33  https://en.wikipedia.org/wiki/Greater_Mexico_City
# 34            https://en.wikipedia.org/wiki/Monterrey
# 35                 https://en.wikipedia.org/wiki/Lima
# 36              https://en.wikipedia.org/wiki/Chicago
# 37  https://en.wikipedia.org/wiki/Dallas_County,_T...
# 38  https://en.wikipedia.org/wiki/Wayne_County,_Mi...
# 39              https://en.wikipedia.org/wiki/Houston
# 40  https://en.wikipedia.org/wiki/Marion_County,_I...
# 41  https://en.wikipedia.org/wiki/Los_Angeles_Coun...
# 42        https://en.wikipedia.org/wiki/New_York_City
# 43  https://en.wikipedia.org/wiki/Maricopa_County,...
# 46             https://en.wikipedia.org/wiki/Brisbane
# 47  https://en.wikipedia.org/wiki/Gold_Coast,_Quee...
# 52             https://en.wikipedia.org/wiki/Auckland
#
#                                          Density note
# 5   The death statistic is for Lagos State, but th...
# 7   Used the wikipedia urban statistic, as this is...
# 10                                                NaN
# 11                                                NaN
# 12  The union territory administrative population ...
# 14                                                NaN
# 15  This is the statistic for Osaka prefecture, as...
# 16  Note the metropolitan area statistic is given ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  This is the administrative region correspondin...
# 22  Municipality population and area used, to corr...
# 23  City proper definition of Moscow used to corre...
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  Appears to correspond to SALURBAN derived popu...
# 29  Appears to correspond to SALURBAN derived popu...
# 30  Appears to correspond to SALURBAN derived popu...
# 31  Appears to correspond to SALURBAN derived popu...
# 32  Appears to correspond to SALURBAN derived popu...
# 33  Appears to correspond to SALURBAN derived popu...
# 34  Appears to correspond to SALURBAN derived popu...
# 35  Appears to correspond to SALURBAN derived popu...
# 36  Death statistic corresponds to city according ...
# 37  Death statistic corresponds to county accordin...
# 38  Death statistic corresponds to county accordin...
# 39  Death statistic appears to correspond to city ...
# 40  Death statistic corresponds to county accordin...
# 41  Death statistic corresponds to county accordin...
# 42  Death statistic corresponds to city according ...
# 43  Death statistic corresponds to county accordin...
# 46                                                NaN
# 47                                                NaN
# 52                                                NaN

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'City', 'pop_wikipedia', 'area_sqkm_wikipedia',
#        'catchment_wikipedia', 'density_wikipedia',
#        'Cumulative deaths reported due to COVID-19', 'deaths_per_100k_pop',
#        'Notes', 'Data source', 'Reported Date', 'Wikipedia page',
#        'Density note'],
#       dtype='object')

# %%
markers=['^']*6
g = sns.lmplot(x="density_wikipedia", 
               y='deaths_per_100k_pop', 
               hue="Region",
               data=df, 
               aspect=2,
               legend=True, 
               fit_reg=False,
               logx=True,
               ci=95,
              truncate=True,
              markers=markers)
sns.regplot(x="density_wikipedia", 
            y='deaths_per_100k_pop', 
            data=df, 
            scatter=False, 
            ax=g.axes[0, 0])
g.map_dataframe(annotate_points,'density_wikipedia','deaths_per_100k_pop','City',df=df.copy())
g.fig.subplots_adjust(top=0.9) # adjust the Figure in rp
g.fig.suptitle('Scatterplot of cumulative deaths reported due to COVID-19\n(approximately March 2020 to Aug 2022) per 100,0000 population\nby population density')
g.set_axis_labels("Population density (km²)", 'Cumulative deaths reported due to COVID-19, per 100,000 population')
g.legend.set_title('Region',prop={'weight':'bold'})
sns.move_legend(g, "upper right")
sns.set_theme(style='white')

# %%
g.fig.savefig('Scatterplot of cumulative deaths reported due to COVID-19.jpg',dpi=300)

# %%
len(df)
# Out:
# 37

# %%
df['Region'].unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'Latin America and the Caribbean',
#        'Northern America', 'Oceania'], dtype=object)
